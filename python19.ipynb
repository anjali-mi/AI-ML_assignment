# %% [markdown]
# <a href="https://colab.research.google.com/github/anjali-mi/AI-ML_assignment/blob/main/python19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load the data
tweets_df = pd.read_csv('/content/amazon_reviews.csv')

# %%
tweets_df
# Out:
#       rating       date         variation  \
# 0          5  31-Jul-18  Charcoal Fabric
# 1          5  31-Jul-18  Charcoal Fabric
# 2          4  31-Jul-18    Walnut Finish
# 3          5  31-Jul-18  Charcoal Fabric
# 4          5  31-Jul-18  Charcoal Fabric
# ...      ...        ...               ...
# 3145       5  30-Jul-18        Black  Dot
# 3146       5  30-Jul-18        Black  Dot
# 3147       5  30-Jul-18        Black  Dot
# 3148       5  30-Jul-18        White  Dot
# 3149       4  29-Jul-18        Black  Dot
#
#                                        verified_reviews  feedback
# 0                                         Love my Echo!         1
# 1                                             Loved it!         1
# 2     Sometimes while playing a game, you can answer...         1
# 3     I have had a lot of fun with this thing. My 4 ...         1
# 4                                                 Music         1
# ...

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rating            3150 non-null   int64
#  1   date              3150 non-null   object
#  2   variation         3150 non-null   object
#  3   verified_reviews  3149 non-null   object
#  4   feedback          3150 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 123.2+ KB

# %%
tweets_df.describe()
# Out:
#             rating     feedback
# count  3150.000000  3150.000000
# mean      4.463175     0.918413
# std       1.068506     0.273778
# min       1.000000     0.000000
# 25%       4.000000     1.000000
# 50%       5.000000     1.000000
# 75%       5.000000     1.000000
# max       5.000000     1.000000

# %%
# Count the occurrences of each label
label_counts = tweets_df['label'].value_counts()
print(label_counts)

# Plot the label counts
plt.figure(figsize=(8, 6))
sns.countplot(x='label', data=tweets_df)
plt.title('Distribution of Labels')
plt.xlabel('Label')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b1a5d9af7785> in <cell line: 2>()
#       1 # Count the occurrences of each label
# ...

# %%
# Count the occurrences of each label
# Check if the 'label' column exists, if not check similar names or column index
print(tweets_df.columns)  # Print column names for inspection

# If 'label' is not present, replace 'label' with the actual column name or index
# For example, if the label column is named 'rating', then:
label_counts = tweets_df['rating'].value_counts()
# Or if the label column is the first column (index 0):
# label_counts = tweets_df.iloc[:, 0].value_counts()

print(label_counts)

# Plot the label counts
plt.figure(figsize=(8, 6))
# Replace 'label' with the actual column name or index in sns.countplot as well
sns.countplot(x='rating', data=tweets_df)
plt.title('Distribution of Labels')
plt.xlabel('Label')
plt.ylabel('Count')
plt.show()
# Out:
# Index(['rating', 'date', 'variation', 'verified_reviews', 'feedback'], dtype='object')
# rating
# 5    2286
# 4     455
# 1     161
# 3     152
# 2      96
# Name: count, dtype: int64

# %%
# load the data
reviews_df = pd.read_csv('/content/amazon_reviews.csv')
reviews_df
# Out:
#       rating       date         variation  \
# 0          5  31-Jul-18  Charcoal Fabric
# 1          5  31-Jul-18  Charcoal Fabric
# 2          4  31-Jul-18    Walnut Finish
# 3          5  31-Jul-18  Charcoal Fabric
# 4          5  31-Jul-18  Charcoal Fabric
# ...      ...        ...               ...
# 3145       5  30-Jul-18        Black  Dot
# 3146       5  30-Jul-18        Black  Dot
# 3147       5  30-Jul-18        Black  Dot
# 3148       5  30-Jul-18        White  Dot
# 3149       4  29-Jul-18        Black  Dot
#
#                                        verified_reviews  feedback
# 0                                         Love my Echo!         1
# 1                                             Loved it!         1
# 2     Sometimes while playing a game, you can answer...         1
# 3     I have had a lot of fun with this thing. My 4 ...         1
# 4                                                 Music         1
# ...

# %%
#view the  dataframe information
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rating            3150 non-null   int64
#  1   date              3150 non-null   object
#  2   variation         3150 non-null   object
#  3   verified_reviews  3149 non-null   object
#  4   feedback          3150 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 123.2+ KB

# %%
rows_with_missing_values = reviews_df[reviews_df['verified_reviews'].isnull()]

print("\nrows with missing verified reviews:")
rows_with_missing_values
# Out:
# rows with missing verified reviews:
#      rating       date variation verified_reviews  feedback
# 473       2  29-Jun-18     White              NaN         0

# %%
if 437 in reviews_df.index:
    reviews_df= reviews_df.drop(437)

# %%
# view the dataframe information
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3149 entries, 0 to 3149
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rating            3149 non-null   int64
#  1   date              3149 non-null   object
#  2   variation         3149 non-null   object
#  3   verified_reviews  3148 non-null   object
#  4   feedback          3149 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 147.6+ KB

# %%
# plot the count plot for the ratings
sns.countplot(x= reviews_df['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
# lets get the length of the verified_reviews column
reviews_df['length'] = reviews_df['verified_reviews'].apply(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-4773be9c6b7c> in <cell line: 2>()
#       1 # lets get the length of the verified_reviews column
# ----> 2 reviews_df['length'] = reviews_df['verified_reviews'].apply(len)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
# ...

# %%
# lets get the length of the verified_reviews column, handling non-string values
reviews_df['length'] = reviews_df['verified_reviews'].apply(lambda x: len(str(x)) if x is not np.nan else 0)

# %%
reviews_df
# Out:
#       rating       date         variation  \
# 0          5  31-Jul-18  Charcoal Fabric
# 1          5  31-Jul-18  Charcoal Fabric
# 2          4  31-Jul-18    Walnut Finish
# 3          5  31-Jul-18  Charcoal Fabric
# 4          5  31-Jul-18  Charcoal Fabric
# ...      ...        ...               ...
# 3145       5  30-Jul-18        Black  Dot
# 3146       5  30-Jul-18        Black  Dot
# 3147       5  30-Jul-18        Black  Dot
# 3148       5  30-Jul-18        White  Dot
# 3149       4  29-Jul-18        Black  Dot
#
#                                        verified_reviews  feedback  length
# 0                                         Love my Echo!         1      13
# 1                                             Loved it!         1       9
# 2     Sometimes while playing a game, you can answer...         1     195
# 3     I have had a lot of fun with this thing. My 4 ...         1     172
# 4                                                 Music         1       5
# ...

# %%
sns.countplot(x = reviews_df['feedback'])
# Out:
# <Axes: xlabel='feedback', ylabel='count'>

# %%
# prompt: also count number in feedback
feedback_counts = reviews_df['feedback'].value_counts()
print(feedback_counts)
# Out:
# feedback
# 1    2892
# 0     257
# Name: count, dtype: int64

# %% [markdown]
# final project solution task#2:plot worldcloud

# %%
#obtain only the positive reviews
positive = reviews_df[reviews_df['feedback'] == '1']
positive
# Out:
# Empty DataFrame
# Columns: [rating, date, variation, verified_reviews, feedback, length]
# Index: []

# %%
# obtain the negative reviews only
negative = reviews_df[reviews_df['feedback'] == '0']
negative
# Out:
# Empty DataFrame
# Columns: [rating, date, variation, verified_reviews, feedback, length]
# Index: []

# %%
#convert to list format
sentences = positive['verified_reviews'].tolist()
len(sentences)
#join all the reviews into one large string
sentences_as_one_string = ' '.join(sentences)
sentences_as_one_string
# Out:
# ''

# %%
from wordcloud import WordCloud
plt.figure(figsize=(10, 8))
plt.imshow(WordCloud().generate(sentences_as_one_string))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-5ac663e5c2ab> in <cell line: 3>()
#       1 from wordcloud import WordCloud
#       2 plt.figure(figsize=(10, 8))
# ----> 3 plt.imshow(WordCloud().generate(sentences_as_one_string))
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate(self, text)
#     640         self
#     641         """
# --> 642         return self.generate_from_text(text)
#     643
#     644     def _check_generated(self):
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     622         """
#     623         words = self.process_text(text)
# --> 624         self.generate_from_frequencies(words)
#     625         return self
#     626
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
# ...

# %%
#obtain only the positive reviews, ensure 'feedback' is treated as a string
positive = reviews_df[reviews_df['feedback'] == '1']

# Check if the 'positive' DataFrame is empty
if positive.empty:
    print("No positive reviews found. Please check your data.")
else:
    #convert to list format
    sentences = positive['verified_reviews'].tolist()

    #join all the reviews into one large string
    sentences_as_one_string = ' '.join(sentences)

    # Check if the joined string is empty
    if not sentences_as_one_string:
        print("Joined string is empty. Please check your data.")
    else:
        from wordcloud import WordCloud
        import matplotlib.pyplot as plt # Import matplotlib.pyplot

        plt.figure(figsize=(10, 8))
        plt.imshow(WordCloud().generate(sentences_as_one_string))
        plt.show() # Display the plot
# Out:
# No positive reviews found. Please check your data.

# %%
#convert to list format
sentences = negative['verified_reviews'].tolist()
len(sentences)
#join all the reviews into one large string
sentences_as_one_string = ' '.join(sentences)
sentences_as_one_string
# Out:
# ''

# %%
from wordcloud import WordCloud
plt.figure(figsize=(20,20))
plt.imshow(WordCloud().generate(sentences_as_one_string))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-4242e688a31e> in <cell line: 3>()
#       1 from wordcloud import WordCloud
#       2 plt.figure(figsize=(20,20))
# ----> 3 plt.imshow(WordCloud().generate(sentences_as_one_string))
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate(self, text)
#     640         self
#     641         """
# --> 642         return self.generate_from_text(text)
#     643
#     644     def _check_generated(self):
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     622         """
#     623         words = self.process_text(text)
# --> 624         self.generate_from_frequencies(words)
#     625         return self
#     626
#
# /usr/local/lib/python3.10/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
# ...

# %%
#convert to list format
sentences = negative['verified_reviews'].tolist()
len(sentences)
#join all the reviews into one large string
sentences_as_one_string = ' '.join(sentences)

# Check if sentences_as_one_string is empty or contains only whitespace
if sentences_as_one_string.strip():
    from wordcloud import WordCloud
    import matplotlib.pyplot as plt

    plt.figure(figsize=(20, 20))
    plt.imshow(WordCloud().generate(sentences_as_one_string))
    plt.show()
else:
    print("The input text for the word cloud is empty or contains only whitespace. Please check your data or preprocessing steps.")
# Out:
# The input text for the word cloud is empty or contains only whitespace. Please check your data or preprocessing steps.
